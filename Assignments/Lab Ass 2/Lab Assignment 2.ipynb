# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('TEC.csv')
col=["TIME", "EMAILADD", "NAME", "EMAIL", "ROLL", "PRN", "NUM", "FESEM1", "FESEM2", "SESEM1", "SESEM2"]
df.columns=col
df.head(15)
# Out:
#                TIME                                 EMAILADD  \
# 0   1/17/2022 12:45            sejal.zambare19@pccoepune.org
# 1   1/17/2022 12:45         rushikesh.thorat19@pccoepune.org
# 2   1/17/2022 12:46          atharv.sontakke19@pccoepune.org
# 3   1/17/2022 12:46          amisha.sherekar19@pccoepune.org
# 4   1/17/2022 12:46       saurabh.sawardekar19@pccoepune.org
# 5   1/17/2022 12:48  priyanka.kizhekethottam19@pccoepune.org
# 6   1/17/2022 12:48        janhavi.pimplikar19@pccoepune.org
# 7   1/17/2022 12:48           lalit.shirsath19@pccoepune.org
# 8   1/17/2022 12:48            shishir.singh19@pccoepune.org
# 9   1/17/2022 12:49       vighnesh.pathrikar19@pccoepune.org
# 10  1/17/2022 12:49            vedant.nerkar19@pccoepune.org
# 11  1/17/2022 12:51         twinkle.shirsath19@pccoepune.org
# 12  1/17/2022 12:51       akshay.siddannavar19@pccoepune.org
# 13  1/17/2022 12:51            avadhut.joshi19@pccoepune.org
# ...

# %%
df.shape
# Out:
# (64, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of                TIME                            EMAILADD  \
# 0   1/17/2022 12:45       sejal.zambare19@pccoepune.org
# 1   1/17/2022 12:45    rushikesh.thorat19@pccoepune.org
# 2   1/17/2022 12:46     atharv.sontakke19@pccoepune.org
# 3   1/17/2022 12:46     amisha.sherekar19@pccoepune.org
# 4   1/17/2022 12:46  saurabh.sawardekar19@pccoepune.org
# ..              ...                                 ...
# 59   1/20/2022 9:24      pratik.meshram20@pccoepune.org
# 60   1/20/2022 9:36         prasad.zore19@pccoepune.org
# 61   1/20/2022 9:42         sudhir.varu19@pccoepune.org
# 62  1/20/2022 10:22  bhagyashree.takale19@pccoepune.org
# 63  1/20/2022 10:38    sarvesh.waghmare19@pccoepune.org
#
#                          NAME                               EMAIL  ROLL  \
# 0               Sejal Zambare           sejal.zambare19@gmail.com   359
# 1      Rushikesh Vilas Thorat    rushikesh.thorat19@pccoepune.org   347
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TIME      64 non-null     object
#  1   EMAILADD  64 non-null     object
#  2   NAME      64 non-null     object
#  3   EMAIL     64 non-null     object
#  4   ROLL      64 non-null     int64
#  5   PRN       64 non-null     object
#  6   NUM       64 non-null     int64
#  7   FESEM1    64 non-null     float64
#  8   FESEM2    64 non-null     float64
#  9   SESEM1    64 non-null     float64
#  10  SESEM2    64 non-null     float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 5.6+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                TIME                            EMAILADD  \
# 0   1/17/2022 12:45       sejal.zambare19@pccoepune.org
# 1   1/17/2022 12:45    rushikesh.thorat19@pccoepune.org
# 2   1/17/2022 12:46     atharv.sontakke19@pccoepune.org
# 3   1/17/2022 12:46     amisha.sherekar19@pccoepune.org
# 4   1/17/2022 12:46  saurabh.sawardekar19@pccoepune.org
# ..              ...                                 ...
# 59   1/20/2022 9:24      pratik.meshram20@pccoepune.org
# 60   1/20/2022 9:36         prasad.zore19@pccoepune.org
# 61   1/20/2022 9:42         sudhir.varu19@pccoepune.org
# 62  1/20/2022 10:22  bhagyashree.takale19@pccoepune.org
# 63  1/20/2022 10:38    sarvesh.waghmare19@pccoepune.org
#
#                          NAME                               EMAIL  ROLL  \
# 0               Sejal Zambare           sejal.zambare19@gmail.com   359
# 1      Rushikesh Vilas Thorat    rushikesh.thorat19@pccoepune.org   347
# ...

# %%
sns.pairplot(df)

# %%
df[df["FESEM1"]>10]
# Out:
#               TIME                      EMAILADD                    NAME  \
# 32  1/18/2022 9:48  rutuja.patil20@pccoepune.org  Rutuja Shantaram Patil
#
#                            EMAIL  ROLL        PRN         NUM  FESEM1  FESEM2  \
# 32  rutuja.patil20@pccoepune.org   376  72164282K  9518771019    95.0    95.0
#
#     SESEM1  SESEM2
# 32     9.4     9.9

# %%
df.loc[32,"FESEM1"]=9.5
df.loc[32, "FESEM2"]=9.5

# %%
df = df[df["FESEM1"]>0]

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['ROLL'], df['FESEM1'])
ax.set_xlabel('roll no of the students')
ax.set_ylabel('grades in sem 1')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['ROLL'], df['FESEM2'])
ax.set_xlabel('roll no of the students')
ax.set_ylabel('grades in sem 2')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['ROLL'], df['SESEM1'])
ax.set_xlabel('roll no of the students')
ax.set_ylabel('grades in sem 1')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df['ROLL'], df['SESEM2'])
ax.set_xlabel('roll no of the students')
ax.set_ylabel('grades in sem 2')
plt.show()
